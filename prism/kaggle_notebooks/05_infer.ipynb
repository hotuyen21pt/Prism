# %% [markdown]
# # Step 5 — Module B: INFER (pool chính thức)
#
# ⚙️ **Bật GPU**
#
# **Máy:** GPU. **Attach:** output Step 4 (checkpoint student cuối) + store.
# **Output:** `outputs/extract/pool_quads.<cohort>.jsonl.gz`.
# Lặp đổi `--cohort` cho: `T-unbiased`, `A-dense`, `B-anchor`, `corpus`.
# > Bỏ `--ckpt` cũng được (tự tìm student cuối). Muốn chắc thì trỏ tay `--ckpt`.
#
# Input tự tìm theo tên file khắp `/kaggle/input` (kể cả output notebook đã attach). Thiếu file nào script báo lỗi rõ 'chạy step X trước'.

# %%
# lấy code mới nhất (bỏ 2 dòng này nếu tắt internet & đã attach repo)
# !rm -rf /kaggle/working/Prism
# !git clone --depth 1 https://github.com/hotuyen21pt/Prism.git /kaggle/working/Prism
P = "/kaggle/working/Prism/prism/scripts/kaggle_pipeline.py"

# %%
# !python {P} --step infer --cohort T-unbiased --batch 2 --score-batch 4 \
  --ckpt /kaggle/input/notebooks/tuyennguyen21pt/pipeline-selftrain/models/selftrain_round2
